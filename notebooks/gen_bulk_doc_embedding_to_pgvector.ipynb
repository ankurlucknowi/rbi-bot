# %%
# !pip install -q langchain langchain_experimental langchain_openai faiss-cpu sentence-transformers==2.2.2 pypdf ipywidgets==7.7.2 psycopg2

# %%
from langchain.document_loaders import TextLoader
from pypdf import PdfReader
from langchain import HuggingFaceHub
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import RetrievalQA, ConversationalRetrievalChain
from langchain.memory import ConversationBufferWindowMemory
import os
from sentence_transformers import SentenceTransformer
import psycopg2
import pandas as pd
import re

# %%
def generate_document_splits(filepath,chunk_size, debug=False):
    splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size,chunk_overlap=30)    
    pages = ''
    with open(filepath, 'r') as file:
        # Read the contents of the file
        if(debug):
            print(f"Processing file {file}:")
        reader = PdfReader(filepath)
        #documentName = file
        for i, page in enumerate(reader.pages):
            page_text = page.extract_text()
            pages += f"pageindicator:{i + 1}:{page_text}\n"    
        splits = splitter.split_text(pages)
        if(debug):
            for i, split in enumerate(splits_1):
                print(f"split {i} {split}",i,split)
        return splits

# %%
def generate_document_embeddings(splits,embedding_model,debug=False):
    embeddings = embedding_model.encode(splits)
    if(debug):
        print(embeddings)
    return embeddings

# %%
def generate_vector_store_df(splits,embeddings,document_domain,document_name,chunk_size,embedding_model_name,debug=False):
    current_page = 1  # Default to page 1
    data = []
    sequence_number = 1
    #for each split - create the vector-db row
    for i,text in enumerate(splits):
        # Check for pageindicator pattern
        match = re.match(r"pageindicator:(\d+):(.*)", text)
        if match:
            # Update the current page based on the indicator
            current_page = int(match.group(1))
            text = match.group(2).strip()  # Remove the indicator and strip extra spaces
        # Append the processed data to the list
        data.append({
            "Document_Domain" : document_domain, 
            "Document_Name": document_name,
            "Page_Number": current_page,
            "Sequence": sequence_number,
            "Chunk_size": chunk_size,
            "Text": text,
            "embedding_model": embedding_model_name,
            "embedding_1024":embeddings[i].astype(float).tolist()
        })
        sequence_number += 1
    df = pd.DataFrame(data)
    if(debug):
        print(df)
    return df

# %% [markdown]
# ## Document embeddings table in pg_vector DB
# CREATE TABLE document_embeddings (
#     Document_Domain VARCHAR(200),
#     Document_Name VARCHAR(200),
#     Page_Number INTEGER,
#     Sequence INTEGER,
#     Chunk_size INTEGER,
#     Text TEXT,
#     embedding_model VARCHAR(200),
#     embedding_1024 vector(1024),
#     UNIQUE (Document_Domain, Document_Name, Sequence)
# );

# %%
def delete_matching_rows(conn, df,debug=False):
    # Check if the DataFrame has at least one row
    if not df.empty:
        # Extract values from the first row
        document_name = df.loc[0, 'Document_Name']
        document_domain = df.loc[0, 'Document_Domain']
        
        cursor = conn.cursor()
        try:
            # Formulate and execute the DELETE statement
            cursor.execute("""
                DELETE FROM document_embeddings
                WHERE Document_Name = %s AND Document_Domain = %s
            """, (document_name, document_domain))
            # Commit the changes
            conn.commit()
            if(debug):
                print(f"Rows with Document_Name '{document_name}' and Document_Domain '{document_domain}' deleted successfully.")
        except Exception as e:
            print("An error occurred:", e)
            conn.rollback()  # Rollback in case of any error
    else:
        if(debug):
            print("DataFrame is empty, no rows to delete.")

# %%
def update_document_embeddings(db_params, df,debug=False):
    # Establish a connection to the database
    conn = psycopg2.connect(
        dbname=db_params['dbname'],
        user=db_params['user'],
        password=db_params['password'],
        host=db_params['host'],
        port=db_params['port']
    )
    delete_matching_rows(conn,df,debug)
    cursor = conn.cursor()
    try:
        # Iterate through the dataframe
        for index, row in df.iterrows():
            # Insert new row
            cursor.execute("""
                INSERT INTO document_embeddings (Document_Domain, Document_Name, Page_Number, Sequence, Chunk_size, Text, embedding_model, embedding_1024)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
            """, (
                row['Document_Domain'],
                row['Document_Name'],
                row['Page_Number'],
                row['Sequence'],
                row['Chunk_size'],
                row['Text'],
                row['embedding_model'],
                list(row['embedding_1024'])  # Ensure embeddings are inserted as an array
            ))
        # Commit the changes
        conn.commit()
    except Exception as e:
        print("An error occurred:", e)
        conn.rollback()  # Rollback in case of any error
    finally:
        # Close the connection and cursor
        cursor.close()
        conn.close()

# %%
def process_document(document_domain,file_path,db_params,embedding_model,chunk_size,debug=False):
    document_name = os.path.basename(file_path)
    splits = generate_document_splits(file_path,chunk_size, debug)
    embeddings = generate_document_embeddings(splits,embedding_model,debug)
    df = generate_vector_store_df(splits,embeddings,document_domain,document_name,chunk_size,embedding_model_name,debug)
    update_document_embeddings(db_params, df,debug=debug)

# %%
def process_directory(directory, run_id,document_domain,db_params,embedding_model,chunk_size,debug):
    processed_dir = os.path.join(directory, f'processed_{run_id}')
    
    # Create processed directory if it does not exist
    if not os.path.exists(processed_dir):
        os.makedirs(processed_dir)
        print(f"Created directory: {processed_dir}")
    
    # Process files in the directory
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        
        # Check if the file is not a directory and not already processed
        if os.path.isfile(file_path) and not os.path.exists(os.path.join(processed_dir, filename)):
            if filename.endswith('.DS_Store'):
                continue
            # Process the file
            print(f"Processing {file_path}...")
            process_document(document_domain,file_path,db_params,embedding_model,chunk_size,debug)
            # Create a dummy file in the processed directory
            open(os.path.join(processed_dir, filename), 'a').close()
            print(f"Marked as processed: {filename}")

# %%
# Initialize variables
document_domain = "RBI_Guidelines"
directory = '/Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/'
dbname = 'rbi_bot_db'
dbuser = 'rbi_bot_user'
dbpassword = 'rbi_bot_pwd'
dbhost = '127.0.0.1'
dbport = 5432
chunk_size = 400
embedding_model_name = 'thenlper/gte-large'
embedding_model = SentenceTransformer(embedding_model_name)
db_params = {
    'dbname': dbname ,
    'user': dbuser,
    'password': dbpassword,
    'host': dbhost,
    'port': dbport
}
run_id = '15May_2'
process_directory(directory, run_id,document_domain,db_params,embedding_model,chunk_size,False)
# Out:
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/LIBOR4B79B1870D234E3FACC2EE378D8F6F84.pdf...
# Marked as processed: LIBOR4B79B1870D234E3FACC2EE378D8F6F84.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/22MC894E2203DDDF4E0ABCA714DCE21F8F6C.pdf...
# Marked as processed: 22MC894E2203DDDF4E0ABCA714DCE21F8F6C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTIEC406443DAEB4529A479B8C8160CE8AD.pdf...
# Marked as processed: NOTIEC406443DAEB4529A479B8C8160CE8AD.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/164DPSSIRBA234EEFCA0445FE97DEF6A608514CD4.pdf...
# Marked as processed: 164DPSSIRBA234EEFCA0445FE97DEF6A608514CD4.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT20042020_EN97FB72E765504BC4AB499A3E4799A254.pdf...
# Marked as processed: NT20042020_EN97FB72E765504BC4AB499A3E4799A254.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NGS202911011691CE62B3EE34489F92568053DD121DF7.pdf...
# Marked as processed: NGS202911011691CE62B3EE34489F92568053DD121DF7.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT33960A003F30AF4DB0927E15FA9E05B3AD.pdf...
# Marked as processed: NT33960A003F30AF4DB0927E15FA9E05B3AD.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MS2604201956598F9FDAFA47E68682559F73E20E80.pdf...
# Marked as processed: MS2604201956598F9FDAFA47E68682559F73E20E80.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT16929C16F7ECD774308BBFAB06824F897A1.pdf...
# Marked as processed: NT16929C16F7ECD774308BBFAB06824F897A1.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT88CF9DC47368A842CEB727122B1F5DC383.pdf...
# Marked as processed: NT88CF9DC47368A842CEB727122B1F5DC383.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/GS202614BEF13D02804839A3F6EDAE84E1FE3F.pdf...
# Marked as processed: GS202614BEF13D02804839A3F6EDAE84E1FE3F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/04NT01042024AA5190D36FBA40C38972F3D69ABC4848.pdf...
# Marked as processed: 04NT01042024AA5190D36FBA40C38972F3D69ABC4848.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT843D0A5750BF454FA89C07C15976BFE29C.pdf...
# Marked as processed: NT843D0A5750BF454FA89C07C15976BFE29C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/FEMA12082022FAF179750C5F402B91C9488A239A6E09.pdf...
# Marked as processed: FEMA12082022FAF179750C5F402B91C9488A239A6E09.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI48EA7D9A680B574A57A68535D992A54795.pdf...
# Marked as processed: NOTI48EA7D9A680B574A57A68535D992A54795.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT1282DB85ECABE3D48FE9473551BA28AC55F.pdf...
# Marked as processed: NT1282DB85ECABE3D48FE9473551BA28AC55F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI61BBAF63FB732E4C46A8149975C0481D34.pdf...
# Marked as processed: NOTI61BBAF63FB732E4C46A8149975C0481D34.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT388079827C2D574CECBBEBB64DA9D5701F.pdf...
# Marked as processed: NT388079827C2D574CECBBEBB64DA9D5701F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MD216AECA1E90A764A27B9378DC0AFDB9A08.pdf...
# Marked as processed: MD216AECA1E90A764A27B9378DC0AFDB9A08.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MD18KYCF6E92C82E1E1419D87323E3869BC9F13.pdf...
# Marked as processed: MD18KYCF6E92C82E1E1419D87323E3869BC9F13.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI355ADA649C0F874E138D5EB01030E4A72D.pdf...
# Marked as processed: NOTI355ADA649C0F874E138D5EB01030E4A72D.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/BANKCIRCULARA39F07C7247D4D4D9C90F4EB0CAF5D96.pdf...
# Marked as processed: BANKCIRCULARA39F07C7247D4D4D9C90F4EB0CAF5D96.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT2240AEB884212B343F78CB5A7D63BA43688.pdf...
# Marked as processed: NT2240AEB884212B343F78CB5A7D63BA43688.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/44FPII84839F6569834341AB66803B079BF59E.pdf...
# Marked as processed: 44FPII84839F6569834341AB66803B079BF59E.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT1331BBCD905C0FC43678B6471648E5DF2E4.pdf...
# Marked as processed: NT1331BBCD905C0FC43678B6471648E5DF2E4.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/OMNIBUSSROFRAMEWORK5409D9BD06FA4C489ED266763E354DE6.pdf...
# Marked as processed: OMNIBUSSROFRAMEWORK5409D9BD06FA4C489ED266763E354DE6.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/APD3980BCCFB42052458583B12C4D21B20A64.pdf...
# Marked as processed: APD3980BCCFB42052458583B12C4D21B20A64.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/N2033B721EBEB6A8843FBBAFE3C1B1219C99E.pdf...
# Marked as processed: N2033B721EBEB6A8843FBBAFE3C1B1219C99E.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/47EMANDATE39D1306C26AE4B44B2EA0050F23E7E3D.pdf...
# Marked as processed: 47EMANDATE39D1306C26AE4B44B2EA0050F23E7E3D.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/APDIR046ABC73360F594E5F9FA5DE93DB49520C.pdf...
# Marked as processed: APDIR046ABC73360F594E5F9FA5DE93DB49520C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MERGE2509174E1785D950684D919FDECA2BFEB5D245.pdf...
# Marked as processed: MERGE2509174E1785D950684D919FDECA2BFEB5D245.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI9145873989D24C4E8CB878E11CF628D71E.pdf...
# Marked as processed: NOTI9145873989D24C4E8CB878E11CF628D71E.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOT107B278DEAA1D394D6C9CD0C33ACC65A220.pdf...
# Marked as processed: NOT107B278DEAA1D394D6C9CD0C33ACC65A220.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/343MRC4FEBA35E0A8459587AC89804A80C936.pdf...
# Marked as processed: 343MRC4FEBA35E0A8459587AC89804A80C936.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/REGISTRATIONOFFACTORA57E49B549084F1DB06AE5FCDF2279C2.pdf...
# Marked as processed: REGISTRATIONOFFACTORA57E49B549084F1DB06AE5FCDF2279C2.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT146F6A26AD4C30C4ED984F0AE5500CDDF72.pdf...
# Marked as processed: NT146F6A26AD4C30C4ED984F0AE5500CDDF72.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT378F949BD6F7B24EE786ACE239E30E2860.pdf...
# Marked as processed: NT378F949BD6F7B24EE786ACE239E30E2860.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/APDIR28A26F81119C09442CB14050B3EF5156D0.pdf...
# Marked as processed: APDIR28A26F81119C09442CB14050B3EF5156D0.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT1317D2724B2A0B54FBE9FBC43B3D8CD7713.pdf...
# Marked as processed: NT1317D2724B2A0B54FBE9FBC43B3D8CD7713.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CAPITALADEQUACY280220246F854C621F244D3C85EC3AA62EFB9E98.pdf...
# Marked as processed: CAPITALADEQUACY280220246F854C621F244D3C85EC3AA62EFB9E98.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT240B61781A58BEF47E88C71E2FD1F3046FF.pdf...
# Marked as processed: NT240B61781A58BEF47E88C71E2FD1F3046FF.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT33709639F94C9CAD46409FEFC4440ED9ECA4.pdf...
# Marked as processed: NT33709639F94C9CAD46409FEFC4440ED9ECA4.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/C0116N33C47187FA91444ABB8186439DB13F36.pdf...
# Marked as processed: C0116N33C47187FA91444ABB8186439DB13F36.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOT13617AF679745544757B1CEC3CB33ABE0B7.pdf...
# Marked as processed: NOT13617AF679745544757B1CEC3CB33ABE0B7.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CREDITONUPI6DBE2D06A61540D19322CFA718643920.pdf...
# Marked as processed: CREDITONUPI6DBE2D06A61540D19322CFA718643920.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/126IONBFCS852DBFB906C04020BFFFBF9C6DB5D6FD.pdf...
# Marked as processed: 126IONBFCS852DBFB906C04020BFFFBF9C6DB5D6FD.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/EMSN060520194886B0247D2A4DDCB85E94A8C5B8C94C.pdf...
# Marked as processed: EMSN060520194886B0247D2A4DDCB85E94A8C5B8C94C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT239E4CC435EA40947AAA48D2617FDDD1D08.pdf...
# Marked as processed: NT239E4CC435EA40947AAA48D2617FDDD1D08.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT126511F5FCE9ADB43AC86149568C6BB4707.pdf...
# Marked as processed: NT126511F5FCE9ADB43AC86149568C6BB4707.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/FEDSRVA891FFD66D0394235AE0151CB8F46010D.pdf...
# Marked as processed: FEDSRVA891FFD66D0394235AE0151CB8F46010D.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MC1027405CCCCF864596B24C22366055A13D.pdf...
# Marked as processed: MC1027405CCCCF864596B24C22366055A13D.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI225A9B06E088CF1454EA7BE53014941ADC9.pdf...
# Marked as processed: NOTI225A9B06E088CF1454EA7BE53014941ADC9.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MER20082018A31940BD96A048EA9A7E41074D4292FA.pdf...
# Marked as processed: MER20082018A31940BD96A048EA9A7E41074D4292FA.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT994605397520F64C33B0B2FF40AFD79960.pdf...
# Marked as processed: NT994605397520F64C33B0B2FF40AFD79960.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/170FPI85A621943FC94443AB5B7373E1F34667.pdf...
# Marked as processed: 170FPI85A621943FC94443AB5B7373E1F34667.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/67RCBCRERH6CC4B8D3644744EA8773889B8AA67615.pdf...
# Marked as processed: 67RCBCRERH6CC4B8D3644744EA8773889B8AA67615.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT1032F3ED9BA358F4B51A3C651F6C61EBEDA.pdf...
# Marked as processed: NT1032F3ED9BA358F4B51A3C651F6C61EBEDA.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/RATEHIKEA517F516F6F44A229B9509ECBDA24BF7.pdf...
# Marked as processed: RATEHIKEA517F516F6F44A229B9509ECBDA24BF7.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI312E25394126E1447E085599C90B5862B83.pdf...
# Marked as processed: NOTI312E25394126E1447E085599C90B5862B83.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT377AD5DBF037E94E6587D49A365770E05F.pdf...
# Marked as processed: NT377AD5DBF037E94E6587D49A365770E05F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOT645DBE909049AD4E099D556822F10FC26A.pdf...
# Marked as processed: NOT645DBE909049AD4E099D556822F10FC26A.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI176DD88A09482D34A878C5B25EC18ABE5A6.pdf...
# Marked as processed: NOTI176DD88A09482D34A878C5B25EC18ABE5A6.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/12MCPRUDENTIAL9143DDA912A74B1E9C6D03FA1FA8001E.pdf...
# Marked as processed: 12MCPRUDENTIAL9143DDA912A74B1E9C6D03FA1FA8001E.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT40D9B2CEA3A09F4A60B37B88CA5654D91B.pdf...
# Marked as processed: NT40D9B2CEA3A09F4A60B37B88CA5654D91B.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI175CD88250E49F74156850C2D9B312E8DF5.pdf...
# Marked as processed: NOTI175CD88250E49F74156850C2D9B312E8DF5.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT2284F727CDA432B4CD783D898FB2B50AC2F.pdf...
# Marked as processed: NT2284F727CDA432B4CD783D898FB2B50AC2F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI333B7C05B5C48145FF99B59083037267A1.pdf...
# Marked as processed: NOTI333B7C05B5C48145FF99B59083037267A1.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT112389D762C6A2E483CBF28A1B0BDB54CEA.pdf...
# Marked as processed: NT112389D762C6A2E483CBF28A1B0BDB54CEA.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI233A95638F7686C45DB9B9E19B02FD69785.pdf...
# Marked as processed: NOTI233A95638F7686C45DB9B9E19B02FD69785.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT2820702162075B94A7AAC68A019D4329D2A.pdf...
# Marked as processed: NT2820702162075B94A7AAC68A019D4329D2A.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT93FD7AB27046EF4148857BDA1D791B551F.pdf...
# Marked as processed: NT93FD7AB27046EF4148857BDA1D791B551F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CIRCULARWMDACT200557E793D0A811421E9CAEEE56335B2557.pdf...
# Marked as processed: CIRCULARWMDACT200557E793D0A811421E9CAEEE56335B2557.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CR30723D84678983A433180B7A5E8B54B4A6D.pdf...
# Marked as processed: CR30723D84678983A433180B7A5E8B54B4A6D.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/GS2055ADE1A5EAFD8A47868261F52C8AAFD14C.pdf...
# Marked as processed: GS2055ADE1A5EAFD8A47868261F52C8AAFD14C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CDCMCOBC8990730E10467EBC258661E5782A00.pdf...
# Marked as processed: CDCMCOBC8990730E10467EBC258661E5782A00.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT1795ACDC7192AEF4BD1ADB12918BF47F462.pdf...
# Marked as processed: NT1795ACDC7192AEF4BD1ADB12918BF47F462.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/INDONEPALREMITTANCE9593B81D2D304BB0A320C3D981794D29.pdf...
# Marked as processed: INDONEPALREMITTANCE9593B81D2D304BB0A320C3D981794D29.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI1211B5694E5419B466E8213FB4BD3BCFF99.pdf...
# Marked as processed: NOTI1211B5694E5419B466E8213FB4BD3BCFF99.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI91A8FD62C942604735BE8AA4C7C33898A2.pdf...
# Marked as processed: NOTI91A8FD62C942604735BE8AA4C7C33898A2.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/REVIEWRWS3DEF38B18F3F4D45860F92C8F81432FA.pdf...
# Marked as processed: REVIEWRWS3DEF38B18F3F4D45860F92C8F81432FA.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/05MC0104202345FAB06F51F34F0AB869C9FE16D467EF.pdf...
# Marked as processed: 05MC0104202345FAB06F51F34F0AB869C9FE16D467EF.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/IMPORTOFSILVERBYQJ14421A459B4A4682B3F1CC5D16A1A53B.pdf...
# Marked as processed: IMPORTOFSILVERBYQJ14421A459B4A4682B3F1CC5D16A1A53B.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI1878387B5161A0D43B08626757817CCD208.pdf...
# Marked as processed: NOTI1878387B5161A0D43B08626757817CCD208.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/8SBT2003EC08F77A1EA745E4AA9A6865852A9C83.pdf...
# Marked as processed: 8SBT2003EC08F77A1EA745E4AA9A6865852A9C83.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI236439FAE312C84AA18339B08A0EC609F7.pdf...
# Marked as processed: NOTI236439FAE312C84AA18339B08A0EC609F7.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT177361E0168DA69485FA2F9551AB4BF60AF.pdf...
# Marked as processed: NT177361E0168DA69485FA2F9551AB4BF60AF.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/17MIRAC01042022568064ADCFF941B1A5CFEB1E0EABC50C.pdf...
# Marked as processed: 17MIRAC01042022568064ADCFF941B1A5CFEB1E0EABC50C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT2185C56F5E083A5483CB2EE86011406C39F.pdf...
# Marked as processed: NT2185C56F5E083A5483CB2EE86011406C39F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT100204B9C87945142BD98D96752B70B2173.pdf...
# Marked as processed: NT100204B9C87945142BD98D96752B70B2173.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI1619329AAF25609480D98060589DBF58DB8.pdf...
# Marked as processed: NOTI1619329AAF25609480D98060589DBF58DB8.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI1421E55B5BE1B934377BDBDC892F0531353.pdf...
# Marked as processed: NOTI1421E55B5BE1B934377BDBDC892F0531353.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/GS20469AC253CCE3D54E91B03B5DB1EB4FB1F7.pdf...
# Marked as processed: GS20469AC253CCE3D54E91B03B5DB1EB4FB1F7.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT1866EBB0B25C6784653AA93A093DB83B70C.pdf...
# Marked as processed: NT1866EBB0B25C6784653AA93A093DB83B70C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI90298F07AD39794E5D835C3E39993C1054.pdf...
# Marked as processed: NOTI90298F07AD39794E5D835C3E39993C1054.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT05R29032019D909E0787BDE4F15B19FCBE0ED8D957D.pdf...
# Marked as processed: NT05R29032019D909E0787BDE4F15B19FCBE0ED8D957D.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/21IESEXTN9844BA38B5F44230A3ABF7B193B6CD94.pdf...
# Marked as processed: 21IESEXTN9844BA38B5F44230A3ABF7B193B6CD94.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI138800F49EEDBC418A9CB662EB2DEE4759.pdf...
# Marked as processed: NOTI138800F49EEDBC418A9CB662EB2DEE4759.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT181CBE6173844614944AB342305D2DA6DE0.pdf...
# Marked as processed: NT181CBE6173844614944AB342305D2DA6DE0.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CRR443640644FCA4C64928A8AD9739B93A9.pdf...
# Marked as processed: CRR443640644FCA4C64928A8AD9739B93A9.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT85_091117CD52BFD7E8034518B500A158B4A8571B.pdf...
# Marked as processed: NT85_091117CD52BFD7E8034518B500A158B4A8571B.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/97MCSCST202223D0C2864CC6F34C7CB5FB2AE2BED82945.pdf...
# Marked as processed: 97MCSCST202223D0C2864CC6F34C7CB5FB2AE2BED82945.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/133SNC1A5B214D9D8A42A0B7C66A29AFE13577.pdf...
# Marked as processed: 133SNC1A5B214D9D8A42A0B7C66A29AFE13577.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CIRCULARCCB6DB27B9062D14007BD700245BE816F26.pdf...
# Marked as processed: CIRCULARCCB6DB27B9062D14007BD700245BE816F26.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT220497AA3BFAEE4243B29D9FD985F3EB06.pdf...
# Marked as processed: NT220497AA3BFAEE4243B29D9FD985F3EB06.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/GS2024NT3D050E97D34C43A9BA833D9C428A6C88.pdf...
# Marked as processed: GS2024NT3D050E97D34C43A9BA833D9C428A6C88.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/N20RB29574DA17294D5C93E4951B2FC86666.pdf...
# Marked as processed: N20RB29574DA17294D5C93E4951B2FC86666.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT100MSME6745E107E8E04A6199F63F010BE9DBE1.pdf...
# Marked as processed: NT100MSME6745E107E8E04A6199F63F010BE9DBE1.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/GB06122019FFCE706AE9764DAA93F7B88153F279C9.pdf...
# Marked as processed: GB06122019FFCE706AE9764DAA93F7B88153F279C9.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/FEMA237A482EDEB9C647469877E7AB32D04EE0.pdf...
# Marked as processed: FEMA237A482EDEB9C647469877E7AB32D04EE0.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT121AE85753EDEB54A4EA96577156E56CADC.pdf...
# Marked as processed: NT121AE85753EDEB54A4EA96577156E56CADC.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT183B9EB572A165B4A4087BB718380C8DF1B.pdf...
# Marked as processed: NT183B9EB572A165B4A4087BB718380C8DF1B.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT38469ACA4E165D42F595A33EAC29C4B34F.pdf...
# Marked as processed: NT38469ACA4E165D42F595A33EAC29C4B34F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI1871F26056D40844CB286E2558B12EF7C98.pdf...
# Marked as processed: NOTI1871F26056D40844CB286E2558B12EF7C98.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI27512042017AE488474D5034180B8AB13EDDA5A6355.pdf...
# Marked as processed: NOTI27512042017AE488474D5034180B8AB13EDDA5A6355.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT158312115D332614C97B20F467F1B97256B.pdf...
# Marked as processed: NT158312115D332614C97B20F467F1B97256B.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/N2024B4A87676E20C494FB758EAA306F70BB0.pdf...
# Marked as processed: N2024B4A87676E20C494FB758EAA306F70BB0.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT312EF952B9DDC244A51B62AF936E53CBF11.pdf...
# Marked as processed: NT312EF952B9DDC244A51B62AF936E53CBF11.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT73EDEE40AF1C2C4B5FBE3EE35521E90DFF.pdf...
# Marked as processed: NT73EDEE40AF1C2C4B5FBE3EE35521E90DFF.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI228457F1A9191D84367B65D2100A10360A3.pdf...
# Marked as processed: NOTI228457F1A9191D84367B65D2100A10360A3.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/GSEC22122017A47F4A8547E8415C92AA6322B65AB8F4.pdf...
# Marked as processed: GSEC22122017A47F4A8547E8415C92AA6322B65AB8F4.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CURRDBE74789AF9242E7B3C913EAFBADC396.pdf...
# Marked as processed: CURRDBE74789AF9242E7B3C913EAFBADC396.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT1092166F7BF544A4EFCB20122FAC9CE4A9A.pdf...
# Marked as processed: NT1092166F7BF544A4EFCB20122FAC9CE4A9A.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT17144DF8BCA29824951B879D5B34668767A.pdf...
# Marked as processed: NT17144DF8BCA29824951B879D5B34668767A.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/321CN1102166DE8AE4289E045B1BF596576D65FB238.pdf...
# Marked as processed: 321CN1102166DE8AE4289E045B1BF596576D65FB238.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT116B2F4837B319F4225BDA0C53BD989B917.pdf...
# Marked as processed: NT116B2F4837B319F4225BDA0C53BD989B917.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/GSEC23122019978BD7269BF84F329DF333154A1F4062.pdf...
# Marked as processed: GSEC23122019978BD7269BF84F329DF333154A1F4062.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/STRIP0305201895C2C3D737614B3CA7229CFD3AC029EA.pdf...
# Marked as processed: STRIP0305201895C2C3D737614B3CA7229CFD3AC029EA.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/GSEC2201167417E764D057444891D3608A97D54F29.pdf...
# Marked as processed: GSEC2201167417E764D057444891D3608A97D54F29.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT69AFCE5E7AFB7A45C48AFFB35274649B24.pdf...
# Marked as processed: NT69AFCE5E7AFB7A45C48AFFB35274649B24.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT183E58850344F0E44C4A4C2414256327927.pdf...
# Marked as processed: NT183E58850344F0E44C4A4C2414256327927.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT66D63D6F2A1B4443CC93778E0277DA96CA.pdf...
# Marked as processed: NT66D63D6F2A1B4443CC93778E0277DA96CA.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/10MCA66C09ECD99148DF8ABF4C39E7901BFE.pdf...
# Marked as processed: 10MCA66C09ECD99148DF8ABF4C39E7901BFE.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/PENALCHARGES26A3A63141764128942EDBA48A78A491.pdf...
# Marked as processed: PENALCHARGES26A3A63141764128942EDBA48A78A491.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT104DBF31521EB5243479DEFC7370B6D43D7.pdf...
# Marked as processed: NT104DBF31521EB5243479DEFC7370B6D43D7.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MSN11022019CC9C75C240304725AD0FB1F264C5794F.pdf...
# Marked as processed: MSN11022019CC9C75C240304725AD0FB1F264C5794F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CR3059E33AD3329E64355A153A6ACF27B524F.pdf...
# Marked as processed: CR3059E33AD3329E64355A153A6ACF27B524F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CMSN22102018CD315C86CA0A4AEB81E494897641BBC0.pdf...
# Marked as processed: CMSN22102018CD315C86CA0A4AEB81E494897641BBC0.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOT185246CB2BC78DA4F7188740B5528CA73D2.pdf...
# Marked as processed: NOT185246CB2BC78DA4F7188740B5528CA73D2.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CIRCULAR677EC931A7A65E4D99AA957D8E85BC0A2A.pdf...
# Marked as processed: CIRCULAR677EC931A7A65E4D99AA957D8E85BC0A2A.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/APDIR8B3621ADC410B40B7AF779FBCC693B8E8.pdf...
# Marked as processed: APDIR8B3621ADC410B40B7AF779FBCC693B8E8.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/RCBSDISCLOSURE1D84ED21F5E74893B2E1B83EBE915996.pdf...
# Marked as processed: RCBSDISCLOSURE1D84ED21F5E74893B2E1B83EBE915996.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MSNA2404180C8032E263684ABFA3DBB4212F2FDFBF.pdf...
# Marked as processed: MSNA2404180C8032E263684ABFA3DBB4212F2FDFBF.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/259MSFE3EA811D8394E4DD8B6989A714CBCD466.pdf...
# Marked as processed: 259MSFE3EA811D8394E4DD8B6989A714CBCD466.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI324ED60717FC0584FF1B82D5B1A19BAA399.pdf...
# Marked as processed: NOTI324ED60717FC0584FF1B82D5B1A19BAA399.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/114PGRDGSFE164A82CB484CB68002E8E70CCB048D.pdf...
# Marked as processed: 114PGRDGSFE164A82CB484CB68002E8E70CCB048D.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT843C3E37DBE1724CE9AD2CE1FBDA047D30.pdf...
# Marked as processed: NT843C3E37DBE1724CE9AD2CE1FBDA047D30.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTIFICATION8E564046F4824F088FD0D09403384117.pdf...
# Marked as processed: NOTIFICATION8E564046F4824F088FD0D09403384117.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT206B907C2CDEA744542826A19D64D360A27.pdf...
# Marked as processed: NT206B907C2CDEA744542826A19D64D360A27.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CAPITALRETENTION224030BE0B1D422AA97C6043C8986190.pdf...
# Marked as processed: CAPITALRETENTION224030BE0B1D422AA97C6043C8986190.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI1375B208C454E74A1C8A1296DE83550945.pdf...
# Marked as processed: NOTI1375B208C454E74A1C8A1296DE83550945.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT1441F3569567FD94FB8A49077B4CA59BD27.pdf...
# Marked as processed: NT1441F3569567FD94FB8A49077B4CA59BD27.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NGS2045110119CAEACC7C3D4E14B35087E9151C35F3.pdf...
# Marked as processed: NGS2045110119CAEACC7C3D4E14B35087E9151C35F3.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/161MSME5CABC8EC603C458A8F599FE5D2B1A9FB.pdf...
# Marked as processed: 161MSME5CABC8EC603C458A8F599FE5D2B1A9FB.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT45A7F7339CCD6F4411ABE9AA3A18494F3C.pdf...
# Marked as processed: NT45A7F7339CCD6F4411ABE9AA3A18494F3C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/UPI100120203AB8E817DFA44A77B2F0B38790F6578C.pdf...
# Marked as processed: UPI100120203AB8E817DFA44A77B2F0B38790F6578C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI561C3A69557C44E191D43BA652E9690E.pdf...
# Marked as processed: NOTI561C3A69557C44E191D43BA652E9690E.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/24MDE80433C3AC4E44EAB8B8973CC2438810.pdf...
# Marked as processed: 24MDE80433C3AC4E44EAB8B8973CC2438810.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/FEMA22R01032019A976862670E34644A58437E9B891FAE9.pdf...
# Marked as processed: FEMA22R01032019A976862670E34644A58437E9B891FAE9.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT18182C6EAA65D254192AE5C7CD521F627D9.pdf...
# Marked as processed: NT18182C6EAA65D254192AE5C7CD521F627D9.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTIFICATION05082019_E12F91D445EFC44529745DFCF7C5A2510.pdf...
# Marked as processed: NOTIFICATION05082019_E12F91D445EFC44529745DFCF7C5A2510.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/FEMA23R2312201908D2BB536D7A475BB5044BE5E0CD4836.pdf...
# Marked as processed: FEMA23R2312201908D2BB536D7A475BB5044BE5E0CD4836.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MC056F209D2AE16F4D1DB0B124B4C6599AA7.pdf...
# Marked as processed: MC056F209D2AE16F4D1DB0B124B4C6599AA7.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT654004D918027A4A01A82664CF19854D4B.pdf...
# Marked as processed: NT654004D918027A4A01A82664CF19854D4B.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT73_091017826BB4CDDE4F44B2A015CE8E823A05D7.pdf...
# Marked as processed: NT73_091017826BB4CDDE4F44B2A015CE8E823A05D7.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CICSRBIOS202169CBD71E8B4945D9A067C58423677A69.pdf...
# Marked as processed: CICSRBIOS202169CBD71E8B4945D9A067C58423677A69.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NETWORTHCAPITALADEQUACY1EEF35D1B9FA426AAA640D15500BD60D.pdf...
# Marked as processed: NETWORTHCAPITALADEQUACY1EEF35D1B9FA426AAA640D15500BD60D.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/103MDCAPITALREQUIREMENTS50C9076B7D494F259CC908D618297293.pdf...
# Marked as processed: 103MDCAPITALREQUIREMENTS50C9076B7D494F259CC908D618297293.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/RATEHIKE88756231362A4471BC8A3DE27DE0DA39.pdf...
# Marked as processed: RATEHIKE88756231362A4471BC8A3DE27DE0DA39.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MERG1501201852E7B35B7C04489B919573EA55CA8961.pdf...
# Marked as processed: MERG1501201852E7B35B7C04489B919573EA55CA8961.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/217FXPLRP8E60A698FFCA4C3A8A4D1E4642825594.pdf...
# Marked as processed: 217FXPLRP8E60A698FFCA4C3A8A4D1E4642825594.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/APDIR4149E86255563496E80C768875F66C6EB.pdf...
# Marked as processed: APDIR4149E86255563496E80C768875F66C6EB.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/115BILATERAL914F4BE404BB44729CD1CE12478BBED0.pdf...
# Marked as processed: 115BILATERAL914F4BE404BB44729CD1CE12478BBED0.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/UNLAWFULACTIVITIES74EA6DD8755A4698BC8655AB327FC013.pdf...
# Marked as processed: UNLAWFULACTIVITIES74EA6DD8755A4698BC8655AB327FC013.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT227A657D7E575C6461EA39BDEBD03E5A36D.pdf...
# Marked as processed: NT227A657D7E575C6461EA39BDEBD03E5A36D.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MERF271120174E0FFA429F23469AB620E6A3F3E845F4.pdf...
# Marked as processed: MERF271120174E0FFA429F23469AB620E6A3F3E845F4.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MSN2204201964A61870431C41368549F712F8FE55E0.pdf...
# Marked as processed: MSN2204201964A61870431C41368549F712F8FE55E0.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOT45CF9025991045450193508C027671053B.pdf...
# Marked as processed: NOT45CF9025991045450193508C027671053B.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT110508A6EB32BF642E0BDD3E34007A30E49.pdf...
# Marked as processed: NT110508A6EB32BF642E0BDD3E34007A30E49.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT2358988BB2AB792443CA17A0FFE3A012B64.pdf...
# Marked as processed: NT2358988BB2AB792443CA17A0FFE3A012B64.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MSN13052019F5F2FD6659934DF9BEB26332645A8616.pdf...
# Marked as processed: MSN13052019F5F2FD6659934DF9BEB26332645A8616.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT642C29DCE69C264AC198E4BDE2C671F7F2.pdf...
# Marked as processed: NT642C29DCE69C264AC198E4BDE2C671F7F2.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MC06010420225C03B0AFA44847328ED551973F59B0E4.pdf...
# Marked as processed: MC06010420225C03B0AFA44847328ED551973F59B0E4.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI262929ADE8708514AD987D28CA5383D3884.pdf...
# Marked as processed: NOTI262929ADE8708514AD987D28CA5383D3884.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT3799F5533FB6B84FA0AAD42E56783C670F.pdf...
# Marked as processed: NT3799F5533FB6B84FA0AAD42E56783C670F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/SOLONDF01A3A921152B4A388D6A9C46B2D4FE4F.pdf...
# Marked as processed: SOLONDF01A3A921152B4A388D6A9C46B2D4FE4F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI827FB2CBDDD52D4E2C941681CE92E5678C.pdf...
# Marked as processed: NOTI827FB2CBDDD52D4E2C941681CE92E5678C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI20245331609FBB9A48AFA6270044F6B7CDDB.pdf...
# Marked as processed: NOTI20245331609FBB9A48AFA6270044F6B7CDDB.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/APDIR1184BC34C64420B4FC0A2D543A65E988A15.pdf...
# Marked as processed: APDIR1184BC34C64420B4FC0A2D543A65E988A15.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI31935002E4E0B9E41CD90E17F9249627998.pdf...
# Marked as processed: NOTI31935002E4E0B9E41CD90E17F9249627998.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/243LEFE24BAEED650447AC85E57E31CD36CDD9.pdf...
# Marked as processed: 243LEFE24BAEED650447AC85E57E31CD36CDD9.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT1085404663A577943BBB344A37057621C17.pdf...
# Marked as processed: NT1085404663A577943BBB344A37057621C17.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI12F1876719F68842A98FEF35F8C9646C30.pdf...
# Marked as processed: NOTI12F1876719F68842A98FEF35F8C9646C30.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/05MC86AB4DADBB044065B42E355489FB232B.pdf...
# Marked as processed: 05MC86AB4DADBB044065B42E355489FB232B.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT56140917C08568222307448E92C82B71A306F121.pdf...
# Marked as processed: NT56140917C08568222307448E92C82B71A306F121.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT112885A2B4B09DA474782C7C8638DE0D488.pdf...
# Marked as processed: NT112885A2B4B09DA474782C7C8638DE0D488.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/GST202441257CB49790446D8FA2E7B18D32EE90.pdf...
# Marked as processed: GST202441257CB49790446D8FA2E7B18D32EE90.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NMSN0103201970527B0DC9304E7B87D42C6B2569214A.pdf...
# Marked as processed: NMSN0103201970527B0DC9304E7B87D42C6B2569214A.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/APDR3481DAC06282466495AA0A3891C416F5FB2.pdf...
# Marked as processed: APDR3481DAC06282466495AA0A3891C416F5FB2.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/148LENDINGE170B7775B524A70A63657218883D6FA.pdf...
# Marked as processed: 148LENDINGE170B7775B524A70A63657218883D6FA.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI2499854C3AA061A47999612E858E986F94E.pdf...
# Marked as processed: NOTI2499854C3AA061A47999612E858E986F94E.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI41A88FC3F66BC945199FBAB9CCA8443F33.pdf...
# Marked as processed: NOTI41A88FC3F66BC945199FBAB9CCA8443F33.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/112MDSP010420245231CBB994974C658737DD8438EA6B75.pdf...
# Marked as processed: 112MDSP010420245231CBB994974C658737DD8438EA6B75.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/11MDE3181360B2BC944BDABC2D5CC6F877B23.pdf...
# Marked as processed: 11MDE3181360B2BC944BDABC2D5CC6F877B23.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/119MCBGUCBS346E4EB1CF6D4FDA9AF827A80477670C.pdf...
# Marked as processed: 119MCBGUCBS346E4EB1CF6D4FDA9AF827A80477670C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/166GSEC9E1A172E38F64481B94FF74056A0A2D4.pdf...
# Marked as processed: 166GSEC9E1A172E38F64481B94FF74056A0A2D4.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MERG0801201797492C2A2955459BA1AABE34C6374A11.pdf...
# Marked as processed: MERG0801201797492C2A2955459BA1AABE34C6374A11.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/APDIR1696A9FD25B59B46DAB42D327130D2871B.pdf...
# Marked as processed: APDIR1696A9FD25B59B46DAB42D327130D2871B.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/209CCP481A3CE844FE4B1099F5E7406D3521FA.pdf...
# Marked as processed: 209CCP481A3CE844FE4B1099F5E7406D3521FA.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/APDIR07AFB5B474A5A448F88DBF8A4BBFAC166F.pdf...
# Marked as processed: APDIR07AFB5B474A5A448F88DBF8A4BBFAC166F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/APDIR295929BB13DEDA4A179372AC21F8AF4B3F.pdf...
# Marked as processed: APDIR295929BB13DEDA4A179372AC21F8AF4B3F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/APDIRCIRCULARNO02EF4A3A8D73DE4C8580766110773B33A8.pdf...
# Marked as processed: APDIRCIRCULARNO02EF4A3A8D73DE4C8580766110773B33A8.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT15495FA50CD30234C5E8513286094F91CCB.pdf...
# Marked as processed: NT15495FA50CD30234C5E8513286094F91CCB.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT5084B952B31EA7442B85AF04281CF7902B.pdf...
# Marked as processed: NT5084B952B31EA7442B85AF04281CF7902B.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/ENGSEC1111201905DA778E722241B199D158B5419086C0.pdf...
# Marked as processed: ENGSEC1111201905DA778E722241B199D158B5419086C0.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/EBGS08102020A63D27086AFD44D689F5002B28BEFE9C.pdf...
# Marked as processed: EBGS08102020A63D27086AFD44D689F5002B28BEFE9C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/REVERSEREPO098503FBFAC04CB6A774F4AD117154D7.pdf...
# Marked as processed: REVERSEREPO098503FBFAC04CB6A774F4AD117154D7.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CIRCULARREVERSEREPODE792A9B024946C5AA976BAC8C75E835.pdf...
# Marked as processed: CIRCULARREVERSEREPODE792A9B024946C5AA976BAC8C75E835.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT41DB4564996B7E42498D8432F3A3B5B102.pdf...
# Marked as processed: NT41DB4564996B7E42498D8432F3A3B5B102.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI751110171AF373C2E2B94324A3592F20457739FE.pdf...
# Marked as processed: NOTI751110171AF373C2E2B94324A3592F20457739FE.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MSN031220184509C12258DE45A68200034EF4DF8703.pdf...
# Marked as processed: MSN031220184509C12258DE45A68200034EF4DF8703.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/GUIDELINESDIGITALLENDINGD5C35A71D8124A0E92AEB940A7D25BB3.pdf...
# Marked as processed: GUIDELINESDIGITALLENDINGD5C35A71D8124A0E92AEB940A7D25BB3.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/15MCHOUSINGFINANCE41CCA660F0F446AFA500372068A1CA51.pdf...
# Marked as processed: 15MCHOUSINGFINANCE41CCA660F0F446AFA500372068A1CA51.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI129BB26DEA3F5C54198BF24774E1222E61A.pdf...
# Marked as processed: NOTI129BB26DEA3F5C54198BF24774E1222E61A.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI202462EEE51BFC51439CA002AF1D42B00ED6.pdf...
# Marked as processed: NOTI202462EEE51BFC51439CA002AF1D42B00ED6.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI96A08F7C9FDCD64BBD9E0319E82C9478B1.pdf...
# Marked as processed: NOTI96A08F7C9FDCD64BBD9E0319E82C9478B1.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTO362159E3CD1EB9D41C1A1574D34242682F9.pdf...
# Marked as processed: NOTO362159E3CD1EB9D41C1A1574D34242682F9.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT555C66247097B94043988617B61C98B816.pdf...
# Marked as processed: NT555C66247097B94043988617B61C98B816.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI420806202350124F1526374891BF4DAC8011E542CB.pdf...
# Marked as processed: NOTI420806202350124F1526374891BF4DAC8011E542CB.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI1405C77A2160B904987B48E4CFD01C05860.pdf...
# Marked as processed: NOTI1405C77A2160B904987B48E4CFD01C05860.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT810F51DA018C1347D6A9732CDB22CB101A.pdf...
# Marked as processed: NT810F51DA018C1347D6A9732CDB22CB101A.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT6561DBAB87CFF94F9BAF6AA00560A6871D.pdf...
# Marked as processed: NT6561DBAB87CFF94F9BAF6AA00560A6871D.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT176D01EBFAB89EF4B03AFBF7E4EC2EB6864.pdf...
# Marked as processed: NT176D01EBFAB89EF4B03AFBF7E4EC2EB6864.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/250ISS1B6B55D87E8D40FF97D3B93DF923F1A5.pdf...
# Marked as processed: 250ISS1B6B55D87E8D40FF97D3B93DF923F1A5.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MSN26112018C2CF923E39E244D685D5924180C3E38C.pdf...
# Marked as processed: MSN26112018C2CF923E39E244D685D5924180C3E38C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/GS2023898DD54B487D46B196DE43E718A3B795.pdf...
# Marked as processed: GS2023898DD54B487D46B196DE43E718A3B795.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/SHIVALIKSFB1E9F5C62820542669FCA412AF24069FC.pdf...
# Marked as processed: SHIVALIKSFB1E9F5C62820542669FCA412AF24069FC.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT253491CD3896EC4B8F85686479E9BC39E1.pdf...
# Marked as processed: NT253491CD3896EC4B8F85686479E9BC39E1.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT1111D6D4A03530449388EA929EBFB4D05AB.pdf...
# Marked as processed: NT1111D6D4A03530449388EA929EBFB4D05AB.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT82DF2304596CDF461EAB367D1D10C44255.pdf...
# Marked as processed: NT82DF2304596CDF461EAB367D1D10C44255.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NGS20331101163CE64717151C485FB944758B0EC5CFCE.pdf...
# Marked as processed: NGS20331101163CE64717151C485FB944758B0EC5CFCE.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/IOCICS610224B02F128D24444978E1CEDF12EC83135.pdf...
# Marked as processed: IOCICS610224B02F128D24444978E1CEDF12EC83135.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT20771D30136D5DE4FCDB33B74D5E5DA4FDF.pdf...
# Marked as processed: NT20771D30136D5DE4FCDB33B74D5E5DA4FDF.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/233NT16022017B1464E6318CE47239F98ADC60384EEE6.pdf...
# Marked as processed: 233NT16022017B1464E6318CE47239F98ADC60384EEE6.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT1368306A232331B475F8E9BDE6A21F507B4.pdf...
# Marked as processed: NT1368306A232331B475F8E9BDE6A21F507B4.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MD44NSIND2E910DD1FBBB471D8CB2E6F4F424F8FF.pdf...
# Marked as processed: MD44NSIND2E910DD1FBBB471D8CB2E6F4F424F8FF.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI2033F8CA93240673412BAEAF4C2EEFC5FA4D.pdf...
# Marked as processed: NOTI2033F8CA93240673412BAEAF4C2EEFC5FA4D.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/01MDC010116BADB4521C423465C9679DBFA22845C7D.pdf...
# Marked as processed: 01MDC010116BADB4521C423465C9679DBFA22845C7D.pdf
# ...
# Marked as processed: PRUDENTIALB20DA810F3E148B099C113C2457FBF8C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI1683F47E470AC724A759FDF7F57DDFE77C5.pdf...
# Marked as processed: NOTI1683F47E470AC724A759FDF7F57DDFE77C5.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT5221B04452DA204B719D6C51CB7FF3C763.pdf...
# Marked as processed: NT5221B04452DA204B719D6C51CB7FF3C763.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MD10007CE48ADE2FB4BF981444FE1349E3B71.pdf...
# Marked as processed: MD10007CE48ADE2FB4BF981444FE1349E3B71.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT122D41E098D658641D5ACE16DC31AB7D5EE.pdf...
# Marked as processed: NT122D41E098D658641D5ACE16DC31AB7D5EE.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/GS2034D0263E2307CF43F08655443FB0FC3310.pdf...
# Marked as processed: GS2034D0263E2307CF43F08655443FB0FC3310.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOT15284C42492E7B04898811FDAB2FD453A28.pdf...
# Marked as processed: NOT15284C42492E7B04898811FDAB2FD453A28.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI170F341D8DE49C04D4B8382D855A9858583.pdf...
# Marked as processed: NOTI170F341D8DE49C04D4B8382D855A9858583.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MDCR2020F3B2E26984D645C28859EB4135579FF1.pdf...
# Marked as processed: MDCR2020F3B2E26984D645C28859EB4135579FF1.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI520320BDBA5F73456F803772FABFA1508E.pdf...
# Marked as processed: NOTI520320BDBA5F73456F803772FABFA1508E.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI2774F4889F96E5D4D38951FEFE010B04AA6.pdf...
# Marked as processed: NOTI2774F4889F96E5D4D38951FEFE010B04AA6.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI261C4A8E12170C342BF9FB501FEBAC7E95F.pdf...
# Marked as processed: NOTI261C4A8E12170C342BF9FB501FEBAC7E95F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOT179A2BCEB830C3748BCB4A2688354A01584.pdf...
# Marked as processed: NOT179A2BCEB830C3748BCB4A2688354A01584.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/EGSEC02122019D9E81832E99A4B2EA290AE0DCCF66015.pdf...
# Marked as processed: EGSEC02122019D9E81832E99A4B2EA290AE0DCCF66015.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/03MCSHG010420239645FF4954B24F45B8E021401AF6C9D1.pdf...
# Marked as processed: 03MCSHG010420239645FF4954B24F45B8E021401AF6C9D1.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT67F20AA6557EC742488619C35C9F839900.pdf...
# Marked as processed: NT67F20AA6557EC742488619C35C9F839900.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI738905E7D49E734030B47B89C7982E34A0.pdf...
# Marked as processed: NOTI738905E7D49E734030B47B89C7982E34A0.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT93990D854AB43D4FF2A659D93664C3B9B8.pdf...
# Marked as processed: NT93990D854AB43D4FF2A659D93664C3B9B8.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT339E49974699C04B63888EAA6166151597.pdf...
# Marked as processed: NT339E49974699C04B63888EAA6166151597.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CIRCULAR080820226F906DEFCA6541E2BED855694E3D6AE3.pdf...
# Marked as processed: CIRCULAR080820226F906DEFCA6541E2BED855694E3D6AE3.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/90MDCDES010420224121B4A8DAEF4390A2063DF8E7E7A3C1.pdf...
# Marked as processed: 90MDCDES010420224121B4A8DAEF4390A2063DF8E7E7A3C1.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MD03_29031928C70FB929814CFCA72C7D3ED5A0EDE4.pdf...
# Marked as processed: MD03_29031928C70FB929814CFCA72C7D3ED5A0EDE4.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT43D0D6575DBD184C22B71E859294DA1969.pdf...
# Marked as processed: NT43D0D6575DBD184C22B71E859294DA1969.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/01MC010720179FA825279A0F4515AC45A306EE04C43A.pdf...
# Marked as processed: 01MC010720179FA825279A0F4515AC45A306EE04C43A.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI79DCB74968569948B4B04A59AC94D2B338.pdf...
# Marked as processed: NOTI79DCB74968569948B4B04A59AC94D2B338.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI176A19DD95D550A4F91A04ADFAFEBB33960.pdf...
# Marked as processed: NOTI176A19DD95D550A4F91A04ADFAFEBB33960.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/116FPI2CE2D2E74BD54A239A3C55999754FC44.pdf...
# Marked as processed: 116FPI2CE2D2E74BD54A239A3C55999754FC44.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/APDIRMTSSCIMS69E6AD07D063414895D2DCC0F9F3DE3F.pdf...
# Marked as processed: APDIRMTSSCIMS69E6AD07D063414895D2DCC0F9F3DE3F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/UNSC51C7F22C6E404BE6A887D7E6009A358C.pdf...
# Marked as processed: UNSC51C7F22C6E404BE6A887D7E6009A358C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT1984D2A3C777BBB41468897132A0EE6B6FC.pdf...
# Marked as processed: NT1984D2A3C777BBB41468897132A0EE6B6FC.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/EAPDIR25741DB496C94042D6A960F1D6E4AAF735.pdf...
# Marked as processed: EAPDIR25741DB496C94042D6A960F1D6E4AAF735.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MER18032019933FDF5B9CC24FEEAD326B7F28C94D91.pdf...
# Marked as processed: MER18032019933FDF5B9CC24FEEAD326B7F28C94D91.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/74APDIR1511201883D0E20ACDD64A208E03ADE77865A6CC.pdf...
# Marked as processed: 74APDIR1511201883D0E20ACDD64A208E03ADE77865A6CC.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT153A1D504D910BC40DCB15F712133ED734B.pdf...
# Marked as processed: NT153A1D504D910BC40DCB15F712133ED734B.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI9474391923311241EB813104552CE40DB9.pdf...
# Marked as processed: NOTI9474391923311241EB813104552CE40DB9.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI717EF119E2E9DA4726BB0393F197592FF6.pdf...
# Marked as processed: NOTI717EF119E2E9DA4726BB0393F197592FF6.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CIRCULARAMENDMENTTOMDA5CCCE00D45C4B6E8990BCEEE5810A87.pdf...
# Marked as processed: CIRCULARAMENDMENTTOMDA5CCCE00D45C4B6E8990BCEEE5810A87.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/173FMRD10BB25D288FA4B0AA9E0AC8DD26A074D.pdf...
# Marked as processed: 173FMRD10BB25D288FA4B0AA9E0AC8DD26A074D.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT202A45C3359ADFA40D8AB40BC9BCB7FA55E.pdf...
# Marked as processed: NT202A45C3359ADFA40D8AB40BC9BCB7FA55E.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI232AEE2D38A335C4A96991CFBACA4192812.pdf...
# Marked as processed: NOTI232AEE2D38A335C4A96991CFBACA4192812.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT30082019619A9A545FF24D3C8DF0DEE2381FA9A8.pdf...
# Marked as processed: NT30082019619A9A545FF24D3C8DF0DEE2381FA9A8.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/59CONSUMERCREDIT4290B9A19D1B46F8B1C735CE66D440E3.pdf...
# Marked as processed: 59CONSUMERCREDIT4290B9A19D1B46F8B1C735CE66D440E3.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/108MDINTERNALOMBUDSMANCC05402F77BE4F229B59877F341386A4.pdf...
# Marked as processed: 108MDINTERNALOMBUDSMANCC05402F77BE4F229B59877F341386A4.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI1950B0269EB07604C2F8880F106159FE8C5.pdf...
# Marked as processed: NOTI1950B0269EB07604C2F8880F106159FE8C5.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/GS20241C92913F5B8DB450E9B607C1CFEFF073A.pdf...
# Marked as processed: GS20241C92913F5B8DB450E9B607C1CFEFF073A.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/ASSIGNMENTLEADBANK59167A8BED5D4CAEB947E61FCC5EF36A.pdf...
# Marked as processed: ASSIGNMENTLEADBANK59167A8BED5D4CAEB947E61FCC5EF36A.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT38444FECBE54B24F7EBC9064D82758887B.pdf...
# Marked as processed: NT38444FECBE54B24F7EBC9064D82758887B.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MER150720195C04928978B94FF3BABEF88AB8B65D02.pdf...
# Marked as processed: MER150720195C04928978B94FF3BABEF88AB8B65D02.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI31535A3A90DCEDA4CCFA427EAA7B7E99011.pdf...
# Marked as processed: NOTI31535A3A90DCEDA4CCFA427EAA7B7E99011.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/CIR345DBB2D6278DA646A8B5CAC802359AA7A0.pdf...
# Marked as processed: CIR345DBB2D6278DA646A8B5CAC802359AA7A0.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/APDIR40BDC9B74B5D2D4708A8F174E6B91B8A83.pdf...
# Marked as processed: APDIR40BDC9B74B5D2D4708A8F174E6B91B8A83.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI209013C67DFFEE4473CB7188CA42D85027F.pdf...
# Marked as processed: NOTI209013C67DFFEE4473CB7188CA42D85027F.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/APDIRSERIESIFSCSLRS91D40B2590D24CA9B0C6C5575354FE59.pdf...
# Marked as processed: APDIRSERIESIFSCSLRS91D40B2590D24CA9B0C6C5575354FE59.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI10062D55CDAC41B47749D3213030B5E3D99.pdf...
# Marked as processed: NOTI10062D55CDAC41B47749D3213030B5E3D99.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/184SLFPDS5F1EB626C0594ADBA826D9B2FE76FD4B.pdf...
# Marked as processed: 184SLFPDS5F1EB626C0594ADBA826D9B2FE76FD4B.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI125C649371DEA2C4DA3AE763AA5E1311603.pdf...
# Marked as processed: NOTI125C649371DEA2C4DA3AE763AA5E1311603.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT8074B05D46CBA744F6A05179FF02F513E5.pdf...
# Marked as processed: NT8074B05D46CBA744F6A05179FF02F513E5.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/GS20466DA02D7360CF4F648160B3BED3220A69.pdf...
# Marked as processed: GS20466DA02D7360CF4F648160B3BED3220A69.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/FRSB2020DD18E8355FD44E76BB8D066738FCB17B.pdf...
# Marked as processed: FRSB2020DD18E8355FD44E76BB8D066738FCB17B.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/DOMESTICDEPOSITSA3FC0C70AAB34ADB918679E9B052C210.pdf...
# Marked as processed: DOMESTICDEPOSITSA3FC0C70AAB34ADB918679E9B052C210.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT109E231D641DAD34B33AF9E01DFE48390E2.pdf...
# Marked as processed: NT109E231D641DAD34B33AF9E01DFE48390E2.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI68162D8BF0255C4A33A4E79BC88D733F3B.pdf...
# Marked as processed: NOTI68162D8BF0255C4A33A4E79BC88D733F3B.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI21106ADDD3C678943529629D069A5AA843C.pdf...
# Marked as processed: NOTI21106ADDD3C678943529629D069A5AA843C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI01D2887316A334466E862190FC1FCBDE71.pdf...
# Marked as processed: NOTI01D2887316A334466E862190FC1FCBDE71.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI19438D758BEDDEB4CD9B696D13D93ECC2D3.pdf...
# Marked as processed: NOTI19438D758BEDDEB4CD9B696D13D93ECC2D3.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT7046236E0FB4144D6B94B0367F6DF87382.pdf...
# Marked as processed: NT7046236E0FB4144D6B94B0367F6DF87382.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MC9258B2560231E6413084279C422194AC69.pdf...
# Marked as processed: MC9258B2560231E6413084279C422194AC69.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI55F5B16F787E1A4B0EBA0F5B30D7A650B6.pdf...
# Marked as processed: NOTI55F5B16F787E1A4B0EBA0F5B30D7A650B6.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/13MDRD77DCF42C4E64B6C9A83C24EF5D4E188.pdf...
# Marked as processed: 13MDRD77DCF42C4E64B6C9A83C24EF5D4E188.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI898C120D41D0E3465B8552E5467EDD7A56.pdf...
# Marked as processed: NOTI898C120D41D0E3465B8552E5467EDD7A56.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/GS1401201976E923A53658449CAC507815F190F13C.pdf...
# Marked as processed: GS1401201976E923A53658449CAC507815F190F13C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI100B01E223EF9624451BA8E018B63C5AB4C.pdf...
# Marked as processed: NOTI100B01E223EF9624451BA8E018B63C5AB4C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT166162EB2E4AF1741D8B37DBE79F6A0D0AD.pdf...
# Marked as processed: NT166162EB2E4AF1741D8B37DBE79F6A0D0AD.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT4142A9CBCE6AC04882AD2C3B1E8718965C.pdf...
# Marked as processed: NT4142A9CBCE6AC04882AD2C3B1E8718965C.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT2024FE7CFF5F73C9426E9BC9EC913666C22D.pdf...
# Marked as processed: NT2024FE7CFF5F73C9426E9BC9EC913666C22D.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI29_2707178B98F22A56B541928B63FA90FB247789.pdf...
# Marked as processed: NOTI29_2707178B98F22A56B541928B63FA90FB247789.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NTGS01062020D77B75E9A1F141DE8D76E9A231B2E851.pdf...
# Marked as processed: NTGS01062020D77B75E9A1F141DE8D76E9A231B2E851.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/07MIP0101168C51C4CB845342D09E8A4A613B1F1C6D.pdf...
# Marked as processed: 07MIP0101168C51C4CB845342D09E8A4A613B1F1C6D.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI542E7CB9D6246F42A9B13E6B886366A6D4.pdf...
# Marked as processed: NOTI542E7CB9D6246F42A9B13E6B886366A6D4.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/GS2034CF2ED3F5AC6F4570A9A6E6EC7A99EA76.pdf...
# Marked as processed: GS2034CF2ED3F5AC6F4570A9A6E6EC7A99EA76.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NOTI188FE2CD0CB9D964C3D8C24E63CDB954070.pdf...
# Marked as processed: NOTI188FE2CD0CB9D964C3D8C24E63CDB954070.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/NT240CD1C6CC1173946E3AD503D31D45988D2.pdf...
# Marked as processed: NT240CD1C6CC1173946E3AD503D31D45988D2.pdf
# Processing /Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs/MGGS19101730462CCE98E24B8EA32773680F373CFB.pdf...
# Marked as processed: MGGS19101730462CCE98E24B8EA32773680F373CFB.pdf

# %%
import os
def delete_specific_duplicates(directory):
    # List all files in the directory
    files = os.listdir(directory)

    # Prepare to track which files to delete
    to_delete = []

    # Iterate over each file to check for duplicates with specific suffixes
    for file in files:
        # Split the filename from its extension
        base_name, extension = os.path.splitext(file)
        
        # Continue only if the file is a PDF
        if extension.lower() != '.pdf':
            continue
        
        # Check for duplicates like "filename (1)" and "filename 2"
        if base_name.endswith(')'):
            suffix_start = base_name.rfind('(')
            if suffix_start != -1 and base_name[suffix_start:].replace('(', '').replace(')', '').strip().isdigit():
                to_delete.append(file)
        else:
            parts = base_name.rsplit(' ', 1)
            if len(parts) > 1 and parts[1].isdigit():
                to_delete.append(file)

    # Delete the identified duplicate files
    for dup_file in to_delete:
        os.remove(os.path.join(directory, dup_file))
        print(f"Deleted: {dup_file}")

# Directory path
directory = '/Users/sarathnathbuddhiraju/workspaces/sarat_notebooks/data/rbi-docs'
delete_specific_duplicates(directory)
# Out:
# Deleted: 93MDVARIATIONMARGIN29E1715A212F48B89160C223B91ABF74 2.pdf
# Deleted: 115MDCN01042024F088EFA4F3F04DC9968AD7EC6844AFE9 2.pdf
# Deleted: NT46D8F6CFB6BBF341DEBA0B6A301866FED4(1).pdf
# Deleted: 102MDITSERVICES56B33FD530B1433187D75CB7C06C8F70 2.pdf
# Deleted: 71MDPSBS1A00DE17143448F991236A3C505BA69D 2.pdf
# Deleted: CIRCULARKFS1504242AE2500BAF494C2A82442B0B642705C1 2.pdf
# Deleted: MD18KYCF6E92C82E1E1419D87323E3869BC9F13 2.pdf
# Deleted: APDIR5736998BB416FA4828A5D1200573D7BC64(1).pdf
# Deleted: 105MDPRUDENTIALREGULATIONSAIFISCF490815D13A4EE9BD3D48B79DD89285 2.pdf
# Deleted: 101MDPPD80EBE808A91E45CE9BE6B989C188F877 2.pdf
# Deleted: NOT148AB670DEFC004A5AAF203E6C730B79DE 2.pdf
# Deleted: 103MDCAPITALREQUIREMENTS50C9076B7D494F259CC908D618297293 2.pdf
# Deleted: 65MD603579515C5142D2B168D5FA886A2CCB 2.pdf
# Deleted: 68MD667BD1A3E259475FA08F8B407617C923 2.pdf
# Deleted: 108MDINTERNALOMBUDSMANCC05402F77BE4F229B59877F341386A4 2.pdf
# Deleted: NOTI11E02042024A16134430F514F08A0DC7CBAA61CA15A (1).pdf
# Deleted: 06MC010420244D9C0BB6AAF042F1A9EAB5A109220107 (1).pdf
# Deleted: 85MDSTANDARDASSETSBE149B86CD3A4B368A5D24471DAD2300 2.pdf
# Deleted: Utkarsh30122022 (1).pdf
# Deleted: NT220497AA3BFAEE4243B29D9FD985F3EB06 2.pdf
# Deleted: 04MD5127742FD0914D54B5EC4ECA8076F325 2.pdf
# Deleted: MD03_29031928C70FB929814CFCA72C7D3ED5A0EDE4 2.pdf
# Deleted: 13MCINCOMERECOGNITIONC107ADC8932F4928AC81EBD4116F59B0 2.pdf
# Deleted: 82MDPPIS2708202181CF0A6FCD1B47B88CAE8E92A228B160 2.pdf
# Deleted: 03MCGUARCOA0104202471E5C2241C52434886F5183D7BF0CB19 2.pdf
# Deleted: 89MDCD45D92E34D84C2695DF6977E4298BFF 2.pdf
# Deleted: MD59073FB085A702408996EAA31953818FFF 2.pdf
# Deleted: 64MDE1617F2067C546028690756E30B0C0F7 2.pdf
# Deleted: 07MCGBAB0104202417E93F8440D4424AB66FD7E3827E3BC4 2.pdf
# Deleted: 05MC01042024D552E9A92BDF4C4582922AAF02A9B465 2.pdf
# Deleted: 86MDLOANEXPOSURESC6B1DFB428C349D885619396317F04DE 2.pdf
# Deleted: LEADBANKRESPONSIBILITY12B035C8852B42C5916A34FC73C36305(1).pdf
# Deleted: 56MD24072017E50D0ED63F9B4414AA756FF0FC72FB66 2.pdf
# Deleted: 104MDINVESTMENTPORTFOLIOC6B7053A02894342A00142968C70FC82 2.pdf
# Deleted: MD01220220176458378BB80A417592B7CE4DB57B123A 2.pdf
# Deleted: 90MDCDES010420224121B4A8DAEF4390A2063DF8E7E7A3C1 2.pdf
# Deleted: MD75603FFA40C55D4C31B13569FB8EA3B9B7 2.pdf
# Deleted: 01MDC010116BADB4521C423465C9679DBFA22845C7D 2.pdf
# Deleted: 19MCONSCST20242568616E151573407CB84FBA80F74609A4 (1).pdf
# Deleted: 13MCINCOMERECOGNITIONC107ADC8932F4928AC81EBD4116F59B0 (1).pdf
# Deleted: 113MD01042024937B0D0040424E9D9D7FD66B31FCDFD0 (1).pdf
# Deleted: 03MD945692290C104C5595AEDAC89AE78788 2.pdf
# Deleted: 61MD0825F724310142CBB351B33F9C3F80FA 2.pdf
# Deleted: 55MD0A0C769D62074BCEAEC6F40FD8356870 2.pdf
# Deleted: Utkarsh30122022 2.pdf
# Deleted: MD11_04012018B4D0DB4E6DA04CC4B7AF62AA03D902BE 2.pdf
# Deleted: 19MCONSCST20242568616E151573407CB84FBA80F74609A4 2.pdf
# Deleted: 87MDPRUDENTIALNORMSDFC5C0716DBE4DB6A4897AF59BDD9BC6 2.pdf
# Deleted: 76MD0104202105B64EDB81304720A2AB3A7C88AC9276 2.pdf
# Deleted: NOTI09042024327AB770BE9640F48C3597C784A42AA5 2.pdf
# Deleted: 114MD01042024A655EA52DF584B2F83EFDC9EE14318A4 2.pdf
# Deleted: 69MD71C6523DA8B14C8582D9860CEA050BA4 2.pdf
# Deleted: 94MDHEDGIN0DE447B3472143D6B3237D5F605E2ADB 2.pdf
# Deleted: 19MD136AF73A742648C4B28FDEADCBA16D23 2.pdf
# Deleted: 114MD01042024A655EA52DF584B2F83EFDC9EE14318A4 (1).pdf
# Deleted: 5MD2603201979CA1390E9E546869B2A9A92614DEDBF 2.pdf
# Deleted: NOTI09042024327AB770BE9640F48C3597C784A42AA5 (1).pdf
# Deleted: 91MDPPDR01042022EADFF060516C47E49C34DB2C9AA96CE1 2.pdf
# Deleted: MDPSL803EE903174E4C85AFA14C335A5B0909 2.pdf
# Deleted: 31APDIR18042019873A7130CB374187925DE77D0A3ACEFB(1).pdf
# Deleted: CIRCULARWMDACTE860BD8021AA4D83BA2E3B2A5DAD77B0 2.pdf
# Deleted: 100MD03042023F2C548759A2C4E429F295F9A9FC5168F 2.pdf
# Deleted: 16MCDF82CC17C279247FCB66E2A39BDAD38F6 2.pdf
# Deleted: MD53E0706201769D6B56245D7457395560CFE72517E0C 2.pdf
# Deleted: 54MD2A55E3AC724E42C9B6B898A116CBFF56 2.pdf
# Deleted: NOTI212707C18CA277943E4968FA7B1C6CD8D14(1).pdf
# Deleted: CIRCULARSONALIBANKPLCCD083B6483AD4E03AA06A35E695B1213 2.pdf
# Deleted: 115MDCN01042024F088EFA4F3F04DC9968AD7EC6844AFE9 (1).pdf
# Deleted: 106MDNBFCS1910202343073E3EF57A4916AA5042911CD8D562 2.pdf
# Deleted: 01MC01042024E0D6B768164C41678A616F743BF7426B 2.pdf
# Deleted: MD63948FC3860C834CF78DB37990DA108B23 2.pdf
# Deleted: 04NT01042024AA5190D36FBA40C38972F3D69ABC4848 (1).pdf
# Deleted: 62MD_05072018A0D59917AE714AF19E633B28C0D9DD9B 2.pdf
# Deleted: MD20D6FC6F31E8E5458F9E0411F433B7D40A(1).pdf
# Deleted: 66MD251018F4877BBAD69542BC8E7CE352C780B709 2.pdf
# Deleted: 78CALL95561D4E6ED4441EAE8AB0763E9B5DAE 2.pdf
# Deleted: 113MD01042024937B0D0040424E9D9D7FD66B31FCDFD0 2.pdf
# Deleted: 98MD030420232E2F50AF4A6043AF97A5628CFB7D3B56 2.pdf
# Deleted: NT110B29188F1C4624C75808B53ADE5175A88 2.pdf
# Deleted: MD20D6FC6F31E8E5458F9E0411F433B7D40A 2.pdf
# Deleted: MD10007CE48ADE2FB4BF981444FE1349E3B71 2.pdf
# Deleted: 11MDEGS1205163428383952204B77831A3A086E82FDDF 2.pdf
# Deleted: 94MDAHSVRBC80A53F9E5D324A948540B84F580DE15F 2.pdf
# Deleted: NT5080C62E3929DE4D70AABB8136B7B5F647 2.pdf
# Deleted: NOTI773109DABBDE4E4E27B93AB7325962E43A(1).pdf
# Deleted: 80MD21389A0318704E99835FC3013AA49E9A 2.pdf
# Deleted: NT1758544AEC7D474BA4BD84ED73ED91A11A 2.pdf
# Deleted: 09MDD593B2F2D48648C8AB3D37625C9F245D 2.pdf
# Deleted: NT123B4E0FFCD96674167952B57E1ED885504(1).pdf
# Deleted: 111MDONBBPS87BA4103916D4B21AE117F1443020ADB 2.pdf
# Deleted: 97MDFENCCBA829FDFE8B46309498DB166C87D933 2.pdf
# Deleted: 04NT01042024AA5190D36FBA40C38972F3D69ABC4848 2.pdf
# Deleted: 96MD01042023DA2FB58B2639427E86DE9E18CB6A9BA8 2.pdf
# Deleted: 06MC010420244D9C0BB6AAF042F1A9EAB5A109220107 2.pdf
# Deleted: 07MCGBAB0104202417E93F8440D4424AB66FD7E3827E3BC4 (1).pdf
# Deleted: 81MDBANKS25082021BC0CC10147494B67ADAA6285904566BB 2.pdf
# Deleted: MD51170116C65788DE8A564165B74D5FECE0626A73 2.pdf
# Deleted: NOTI1002042024510995E8248A417E955ED0A454117B70 2.pdf
# Deleted: 92MDCREDITDEBITCARDC423AFFB5E7945149C95CDD2F71E9158 2.pdf
# Deleted: 77MD01042021E0839C3AEC50408A8570A02A57D40E4F 2.pdf
# Deleted: 06MDE170516F633150EBCFE438084174F7DECCDC20C 2.pdf
# Deleted: 112MDSP010420245231CBB994974C658737DD8438EA6B75 2.pdf
# Deleted: NOTI11E02042024A16134430F514F08A0DC7CBAA61CA15A 2.pdf
# Deleted: NOTI1002042024510995E8248A417E955ED0A454117B70 (1).pdf
# Deleted: MDP2PB9A1F7F3BDAC463EAF1EEE48A43F2F6C 2.pdf
# Deleted: MD7493544C24B5FC47D0AB12798C61CDB56F 2.pdf
# Deleted: 109MDCPNCD797F42D139D741169EB58E637B243FF6 2.pdf
# Deleted: NT2598D7D5419D594733841C4909FAFD86BE(1).pdf
# Deleted: 88MDRBICDD2022D30B9C6D207C4D47A98D48F169DF1762 2.pdf
# Deleted: 112MDSP010420245231CBB994974C658737DD8438EA6B75 (1).pdf
# Deleted: 99MD7E47D5C894AC429FBA74073AA1D9CB93 2.pdf
# Deleted: 12MDFB8AD1B34BCB4D0A8F6869DA4A53082E 2.pdf
# Deleted: 07MIP0101168C51C4CB845342D09E8A4A613B1F1C6D 2.pdf
# Deleted: 01MC01042024E0D6B768164C41678A616F743BF7426B (1).pdf
# Deleted: NT86_091117DA9D7912DC2548ABA492B2DCBB6B1205(1).pdf
# Deleted: MD11024D1EF9CB39B44ABB23DF586173E0CDE 2.pdf
# Deleted: NOTI163F660CD6819C4F1FAAB9F631B1719741 2.pdf
# Deleted: 05MC01042024D552E9A92BDF4C4582922AAF02A9B465 (1).pdf
# Deleted: 03MCGUARCOA0104202471E5C2241C52434886F5183D7BF0CB19 (1).pdf
# Deleted: 08MDROA112016989330DF1FF9494784DAC32B488E6AE4 2.pdf
# Deleted: 107MDITGOVERNANCE3303572008604C67AC25B84292D85567 2.pdf
# Deleted: 83MDPRESENTATIONDISCLOSUREDADE5C12667549B5B123EC94C73FE5D1 2.pdf
# Deleted: 84MD8DAD7C4F379B4875AC9C2D398646B42D 2.pdf
# Deleted: 02MD787706E669D641C090B415DBE22DEE29 2.pdf
# Deleted: 14MDM1120153F2FD5CC455640E78D139304BC7C080F 2.pdf
